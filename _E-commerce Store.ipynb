# %%
sales_data = [
    {"order_id": 001, "customer": "Anu", "item": "Mouse", "quantity": 2, "price_per_item": 500.0, "order_date": "2025-07-01"},
    {"order_id": 002, "customer": "Binu", "item": "Keyboard", "quantity": 1, "price_per_item": 700.0, "order_date": "2025-07-01"},
    {"order_id": 003, "customer": "sinu", "item": "Notebook", "quantity": 3, "price_per_item": 50.0, "order_date": "2025-07-02"},
    {"order_id": 4, "customer": "vinu", "item": "Pen", "quantity": 5, "price_per_item": 20.0, "order_date": "2025-07-02"},
    {"order_id": 5, "customer": "Evana", "item": "Mouse", "quantity": 1, "price_per_item": 500.0, "order_date": "2025-07-03"},
    {"order_id": 6, "customer": "Fathima", "item": "Headphones", "quantity": 1, "price_per_item": 1200.0, "order_date": "2025-07-03"},
    {"order_id": 7, "customer": "George", "item": "Notebook", "quantity": 2, "price_per_item": 50.0, "order_date": "2025-07-04"},
    {"order_id": 8, "customer": "Hema", "item": "Mouse Pad", "quantity": 1, "price_per_item": 150.0, "order_date": "2025-07-04"},
    {"order_id": 9, "customer": "Ivan", "item": "Pen", "quantity": 10, "price_per_item": 20.0, "order_date": "2025-07-05"},
    {"order_id": 10, "customer": "Julia", "item": "Mouse", "quantity": 1, "price_per_item": 500.0, "order_date": "2025-07-05"},
]


print(sales_data)
# Out:
# [{'order_id': 1, 'customer': 'Alice', 'item': 'Mouse', 'quantity': 2, 'price_per_item': 500.0, 'order_date': '2025-07-01'}, {'order_id': 2, 'customer': 'Bob', 'item': 'Keyboard', 'quantity': 1, 'price_per_item': 700.0, 'order_date': '2025-07-01'}, {'order_id': 3, 'customer': 'Charlie', 'item': 'Notebook', 'quantity': 3, 'price_per_item': 50.0, 'order_date': '2025-07-02'}, {'order_id': 4, 'customer': 'Diana', 'item': 'Pen', 'quantity': 5, 'price_per_item': 20.0, 'order_date': '2025-07-02'}, {'order_id': 5, 'customer': 'Ethan', 'item': 'Mouse', 'quantity': 1, 'price_per_item': 500.0, 'order_date': '2025-07-03'}, {'order_id': 6, 'customer': 'Fatima', 'item': 'Headphones', 'quantity': 1, 'price_per_item': 1200.0, 'order_date': '2025-07-03'}, {'order_id': 7, 'customer': 'George', 'item': 'Notebook', 'quantity': 2, 'price_per_item': 50.0, 'order_date': '2025-07-04'}, {'order_id': 8, 'customer': 'Hema', 'item': 'Mouse Pad', 'quantity': 1, 'price_per_item': 150.0, 'order_date': '2025-07-04'}
# ...
